# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('data_core.csv')

# Display the first few rows of your data
print(df.head())
# Out:
#    Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0         26.0      52.0      38.0     Sandy      Maize        37          0
# 1         29.0      52.0      45.0     Loamy  Sugarcane        12          0
# 2         34.0      65.0      62.0     Black     Cotton         7          9
# 3         32.0      62.0      34.0       Red    Tobacco        22          0
# 4         28.0      54.0      46.0    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
pip install seaborn pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('climate.csv')

# Display the first few rows of your dataset to confirm it's loaded correctly
print(df.head())
# Out:
#        country_name country_code region income_group  \
# 0   INGRESO MEDIANO          MIC    NaN    AGREGADOS
# 1   INGRESO MEDIANO          MIC    NaN    AGREGADOS
# 2   INGRESO MEDIANO          MIC    NaN    AGREGADOS
# 3   INGRESO MEDIANO          MIC    NaN    AGREGADOS
# 4   INGRESO MEDIANO          MIC    NaN    AGREGADOS
#
#                                     indicator_name  indicator_code  year  \
# 0  EXPORTACIONES DE BIENES Y SERVICIOS (% DEL PIB)  NE.EXP.GNFS.ZS  1960
# 1  EXPORTACIONES DE BIENES Y SERVICIOS (% DEL PIB)  NE.EXP.GNFS.ZS  1961
# 2  EXPORTACIONES DE BIENES Y SERVICIOS (% DEL PIB)  NE.EXP.GNFS.ZS  1962
# 3  EXPORTACIONES DE BIENES Y SERVICIOS (% DEL PIB)  NE.EXP.GNFS.ZS  1963
# 4  EXPORTACIONES DE BIENES Y SERVICIOS (% DEL PIB)  NE.EXP.GNFS.ZS  1964
#
#    exports_of_goods_and_services
# 0                      10.091362
# 1                      10.316034
# 2                       9.810639
# 3                      10.824773
# 4                      10.017210

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot with columns 'x_column' and 'y_column' from your dataset
sns.scatterplot(data=df, x='country_code', y='income_group')

# Show the plot
plt.show()

# %%
df = pd.read_excel('data_core.xlsx')
df
# Out:
#       Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0           26.00     52.00     38.00     Sandy      Maize        37
# 1           29.00     52.00     45.00     Loamy  Sugarcane        12
# 2           34.00     65.00     62.00     Black     Cotton         7
# 3           32.00     62.00     34.00       Red    Tobacco        22
# 4           28.00     54.00     46.00    Clayey      Paddy        35
# ...           ...       ...       ...       ...        ...       ...
# 7995        35.30     59.61     44.25     Loamy  Oil seeds        10
# 7996        39.39     71.67     49.34     Black     Barley        35
# 7997        35.79     67.64     45.04       Red     Barley        41
# 7998        37.78     73.38     36.03     Black    Tobacco        10
# 7999        31.38     48.73     62.27     Loamy    Millets        11
#
#       Potassium  Phosphorous Fertilizer Name
# 0             0            0            Urea
# 1             0           36             DAP
# ...

# %%
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('data_core.csv')

# Display the first few rows of your dataset to confirm it's loaded correctly
print(df.head())
# Out:
#    Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0         26.0      52.0      38.0     Sandy      Maize        37          0
# 1         29.0      52.0      45.0     Loamy  Sugarcane        12          0
# 2         34.0      65.0      62.0     Black     Cotton         7          9
# 3         32.0      62.0      34.0       Red    Tobacco        22          0
# 4         28.0      54.0      46.0    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('data_c.csv')

# Scatter plot with columns 'x_column' and 'y_column' from your dataset
sns.scatterplot(data=df, x='Temparature', y='Potassium')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(data=df, x="Temparature", y="Nitrogen")
plt.show()

# %%
sns.histplot(df['Temparature'], kde=False)
# Out:
# <Axes: xlabel='Temparature', ylabel='Count'>

# %%
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('data_core.csv')
sns.jointplot(x='Humidity',y='Phosphorous',data=df,kind='reg') # with regression line

# %%
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('data_core.csv')
sns.jointplot(x='Phosphorous',y='Humidity',data=df,kind='kde')

# %%
# BOX Plot

import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('data_c.csv')

sns.boxplot(x="Potassium",y="Phosphorous",data=df)
# Out:
# <Axes: xlabel='Potassium', ylabel='Phosphorous'>

# %%
# BOX Plot

import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('data_c.csv')
sns.barplot(x='Temparature',y='Nitrogen',data=df,palette='PuRd',ci=None,orient='h')
plt.legend()
plt.show()
# Out:
# C:\Users\namra\AppData\Local\Temp\ipykernel_8288\3279613154.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Temparature',y='Nitrogen',data=df,palette='PuRd',ci=None,orient='h')
# C:\Users\namra\AppData\Local\Temp\ipykernel_8288\3279613154.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Temparature',y='Nitrogen',data=df,palette='PuRd',ci=None,orient='h')
# C:\Users\namra\AppData\Local\Temp\ipykernel_8288\3279613154.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# BOX Plot

import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('data_c.csv')
sns.barplot(x='Temparature',y='Nitrogen',data=df,palette='PuRd',ci=None)
plt.legend()
plt.show()
# Out:
# C:\Users\namra\AppData\Local\Temp\ipykernel_8288\3827293046.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Temparature',y='Nitrogen',data=df,palette='PuRd',ci=None)
# C:\Users\namra\AppData\Local\Temp\ipykernel_8288\3827293046.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Temparature',y='Nitrogen',data=df,palette='PuRd',ci=None)
# C:\Users\namra\AppData\Local\Temp\ipykernel_8288\3827293046.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#flights = flights.pivot("month","year","passengers")
import pandas as pd
import seaborn as sns

# Load your dataset (adjust the file path)
df = pd.read_csv('data_c.csv')
flights_wide = df.pivot(index="Temparature", columns="Humidity", values="Nitrogen")
print(flights_wide)

sns.heatmap(flights_wide,linewidth=0.5,cmap="YlGnBu")
# Out:
# Humidity     52.00  52.86  54.85  55.39  55.66  56.26  56.84  60.02  62.55  \
# Temparature
# 22.33          NaN    NaN    NaN    NaN    NaN    NaN   18.0    NaN    NaN
# 23.66          NaN    NaN    NaN    NaN   38.0    NaN    NaN    NaN    NaN
# 24.51          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   13.0
# 25.20          NaN    NaN    NaN    NaN    NaN    NaN    NaN    8.0    NaN
# 26.00         37.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 28.02          NaN    NaN   10.0    NaN    NaN    NaN    NaN    NaN    NaN
# 28.27          NaN   41.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 28.66          NaN    NaN    NaN    NaN    NaN   37.0    NaN    NaN    NaN
# 29.75          NaN    NaN    NaN   42.0    NaN    NaN    NaN    NaN    NaN
# 30.85          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 33.27          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
#flights = flights.pivot("month","year","passengers")
import pandas as pd

# Load your dataset (adjust the file path)
df = pd.read_csv('data_c.csv')
flights_wide = df.pivot(index="Temparature", columns="Humidity", values="Nitrogen")
print(flights_wide)

sns.heatmap(flights_wide,linewidth=0.5,cmap="YlGnBu")
# Out:
# Humidity     52.00  52.86  54.85  55.39  55.66  56.26  56.84  60.02  62.55  \
# Temparature
# 22.33          NaN    NaN    NaN    NaN    NaN    NaN   18.0    NaN    NaN
# 23.66          NaN    NaN    NaN    NaN   38.0    NaN    NaN    NaN    NaN
# 24.51          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   13.0
# 25.20          NaN    NaN    NaN    NaN    NaN    NaN    NaN    8.0    NaN
# 26.00         37.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 28.02          NaN    NaN   10.0    NaN    NaN    NaN    NaN    NaN    NaN
# 28.27          NaN   41.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 28.66          NaN    NaN    NaN    NaN    NaN   37.0    NaN    NaN    NaN
# 29.75          NaN    NaN    NaN   42.0    NaN    NaN    NaN    NaN    NaN
# 30.85          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 33.27          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
pip install ydata-profiling
import pandas as pd

from ydata_profiling import ProfileReport

df = pd.read_csv("thyroid_cancer_risk_data.csv")

profile = ProfileReport(df,title = "Pandas Profiling Report", explorative=True)

profile.to_file("eda.html")
# Out:
#   Cell In[54], line 1
#     pip install ydata-profiling
#         ^
# SyntaxError: invalid syntax
